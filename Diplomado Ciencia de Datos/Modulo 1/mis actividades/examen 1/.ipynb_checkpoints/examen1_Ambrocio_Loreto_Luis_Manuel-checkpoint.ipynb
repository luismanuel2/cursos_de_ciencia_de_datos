# %%
import pandas as pd
import unicodedata
import re
import jellyfish as jf
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import datetime

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Dataset

# %%
df = pd.read_csv("data_examen.csv")

# %%
df.shape
# Out:
# (600000, 9)

# %%
df
# Out:
#                                   key  fare_amount          pickup_datetime  \
# 0        2012-11-11 13:45:00.00000029         12.5  2012-11-11 13:45:00 UTC
# 1        2010-01-26 00:13:00.00000050         11.3  2010-01-26 00:13:00 UTC
# 2       2014-10-07 19:24:00.000000235         19.5  2014-10-07 19:24:00 UTC
# 3         2012-10-20 13:48:40.0000002         10.5  2012-10-20 13:48:40 UTC
# 4       2014-04-29 20:27:00.000000186          7.0  2014-04-29 20:27:00 UTC
# ...                               ...          ...                      ...
# 599995   2010-07-20 09:21:00.00000052         14.5  2010-07-20 09:21:00 UTC
# 599996    2013-02-20 15:16:27.0000004          3.5  2013-02-20 15:16:27 UTC
# 599997  2010-10-07 22:32:00.000000223          7.3  2010-10-07 22:32:00 UTC
# 599998  2010-09-13 13:28:00.000000138          4.1  2010-09-13 13:28:00 UTC
# 599999    2014-09-03 20:35:37.0000004          8.0  2014-09-03 20:35:37 UTC
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0             -73.956322        40.813427         -73.959143
# 1             -73.982577        40.746018         -73.980713
# 2             -73.972000        40.759470         -74.006190
# 3             -74.002701        40.728209         -74.013599
# 4             -73.982517        40.770782         -73.979932
# ...                  ...              ...                ...
# 599995        -73.979120        40.746182         -74.004187
# 599996        -73.955352        40.804620         -73.955352
# 599997          0.000000         0.000000           0.000000
# 599998        -73.973527        40.784913         -74.001877
# 599999        -73.996540        40.747920         -73.979322
#
#         dropoff_latitude  passenger_count fare_class
# 0              40.783220                1   low_fare
# 1              40.780807                1   low_fare
# 2              40.708460                2   low_fare
# 3              40.710990                1   low_fare
# 4              40.754880                1   low_fare
# ...                  ...              ...        ...
# 599995         40.705937                1   low_fare
# 599996         40.804620                1   low_fare
# 599997          0.000000                2   low_fare
# 599998         40.740657                6   low_fare
# 599999         40.762122                1   low_fare
#
# [600000 rows x 9 columns]

# %%
df.dtypes
# Out:
# key                   object
# fare_amount          float64
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# fare_class            object
# dtype: object

# %%
tot_registos, tot_variables = df.shape

# %% [markdown]
# # Calidad de datos

# %% [markdown]
# ## Etiquetado de variables

# %%
v_feats=["fare_class"]
c_feats=['fare_amount','pickup_longitude','pickup_latitude','dropoff_longitude',
         'dropoff_latitude','passenger_count']
d_feats = ['pickup_datetime']
id_feats = ['key']

c_feats_new=["c_"+x for x in c_feats]
v_feats_new=["v_"+x for x in v_feats]
d_feats_new=["d_"+x for x in d_feats]
id_feats_new=["id_"+x for x in id_feats]

df.rename(columns=dict(zip(c_feats,c_feats_new)),inplace=True)
df.rename(columns=dict(zip(v_feats,v_feats_new)),inplace=True)
df.rename(columns=dict(zip(d_feats,d_feats_new)),inplace=True)
df.rename(columns=dict(zip(id_feats,id_feats_new)),inplace=True)

# %%
df.columns
# Out:
# Index(['id_key', 'c_fare_amount', 'd_pickup_datetime', 'c_pickup_longitude',
#        'c_pickup_latitude', 'c_dropoff_longitude', 'c_dropoff_latitude',
#        'c_passenger_count', 'v_fare_class'],
#       dtype='object')

# %% [markdown]
# ## Duplicidad

# %% [markdown]
# primero vamos a revisar si nuestro identificador de unidad muestral nos sirve

# %%
df['id_key'].describe()
# Out:
# count                           600000
# unique                          600000
# top       2012-11-11 13:45:00.00000029
# freq                                 1
# Name: id_key, dtype: object

# %% [markdown]
# comparamos si id_key y  d_pickup_datetime son iguales

# %%
np.sum(pd.to_datetime(df['id_key'], format="%Y-%m-%d %H:%M:%S.%f")== pd.to_datetime(df['d_pickup_datetime'], format = "%Y-%m-%d %H:%M:%S %Z"))
# Out:
# 0

# %% [markdown]
# revisando la columna id_key observamos que esta tiene fracciones de segundo y d_pickup_datetime solo llega hasta segundos, por eso python no las identifica como iguales, vamos a truncar las columnas hasta segundo y volvemos a comparar

# %%
np.sum(pd.to_datetime(df['id_key'], format="%Y-%m-%d %H:%M:%S.%f").dt.strftime("%Y-%m-%d %H:%M:%S") == pd.to_datetime(df['d_pickup_datetime'], format = "%Y-%m-%d %H:%M:%S %Z").dt.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# 600000

# %% [markdown]
# el resultado es que las dos son iguales(truncando en segundos), por lo que vamos a sustituir d_pickup_datetime por el valor de  id_key (ya que tiene pas presicion por las fracciones de segund), y vamos a eliminar id_key

# %%
df['d_pickup_datetime'] = pd.to_datetime(df['id_key'], format="%Y-%m-%d %H:%M:%S.%f")
df.drop('id_key', axis=1, inplace=True)

# %%
df
# Out:
#         c_fare_amount             d_pickup_datetime  c_pickup_longitude  \
# 0                12.5 2012-11-11 13:45:00.000000290          -73.956322
# 1                11.3 2010-01-26 00:13:00.000000500          -73.982577
# 2                19.5 2014-10-07 19:24:00.000000235          -73.972000
# 3                10.5 2012-10-20 13:48:40.000000200          -74.002701
# 4                 7.0 2014-04-29 20:27:00.000000186          -73.982517
# ...               ...                           ...                 ...
# 599995           14.5 2010-07-20 09:21:00.000000520          -73.979120
# 599996            3.5 2013-02-20 15:16:27.000000400          -73.955352
# 599997            7.3 2010-10-07 22:32:00.000000223            0.000000
# 599998            4.1 2010-09-13 13:28:00.000000138          -73.973527
# 599999            8.0 2014-09-03 20:35:37.000000400          -73.996540
#
#         c_pickup_latitude  c_dropoff_longitude  c_dropoff_latitude  \
# 0               40.813427           -73.959143           40.783220
# 1               40.746018           -73.980713           40.780807
# 2               40.759470           -74.006190           40.708460
# 3               40.728209           -74.013599           40.710990
# 4               40.770782           -73.979932           40.754880
# ...                   ...                  ...                 ...
# 599995          40.746182           -74.004187           40.705937
# 599996          40.804620           -73.955352           40.804620
# 599997           0.000000             0.000000            0.000000
# 599998          40.784913           -74.001877           40.740657
# 599999          40.747920           -73.979322           40.762122
#
#         c_passenger_count v_fare_class
# 0                       1     low_fare
# 1                       1     low_fare
# 2                       2     low_fare
# 3                       1     low_fare
# 4                       1     low_fare
# ...                   ...          ...
# 599995                  1     low_fare
# 599996                  1     low_fare
# 599997                  2     low_fare
# 599998                  6     low_fare
# 599999                  1     low_fare
#
# [600000 rows x 8 columns]

# %% [markdown]
# checamos si a nivel tabla hay duplicados

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# definimos nuestra unidad muestral como c_fare_amount,d_pickup_datetime,c_pickup_longitude ya que la hora exacta y lugar de recogida exacto son eventos unicos, revisamos si hay duplicados considerando estas variables

# %%
df.duplicated(subset = ['c_fare_amount','d_pickup_datetime','c_pickup_longitude']).sum()
# Out:
# 0

# %% [markdown]
# no encontramos datos duplicados

# %% [markdown]
# ## completitud

# %%
df.isnull().sum(axis=0)
# Out:
# c_fare_amount          0
# d_pickup_datetime      0
# c_pickup_longitude     0
# c_pickup_latitude      0
# c_dropoff_longitude    7
# c_dropoff_latitude     7
# c_passenger_count      0
# v_fare_class           0
# dtype: int64

# %%
df[df.isnull().any(axis = 1)]
# Out:
#         c_fare_amount             d_pickup_datetime  c_pickup_longitude  \
# 54649           10.20 2013-11-04 20:59:15.000000100          -73.998460
# 68599           14.76 2011-09-25 23:01:12.000000500          -73.985374
# 186380          12.50 2012-12-11 12:57:00.000000130          -73.992760
# 264084          40.00 2011-06-20 11:34:44.000000100          -73.862900
# 374983          11.80 2011-09-08 09:12:52.000000100          -73.987041
# 378056           7.80 2012-12-11 12:34:20.000000600            0.000000
# 458033           7.20 2013-11-04 20:07:59.000000600          -73.977048
#
#         c_pickup_latitude  c_dropoff_longitude  c_dropoff_latitude  \
# 54649           40.745406                  NaN                 NaN
# 68599           40.768518                  NaN                 NaN
# 186380          40.743098                  NaN                 NaN
# 264084          40.768900                  NaN                 NaN
# 374983          40.751542                  NaN                 NaN
# 378056           0.000000                  NaN                 NaN
# 458033          40.787565                  NaN                 NaN
#
#         c_passenger_count v_fare_class
# 54649                   0     low_fare
# 68599                   0     low_fare
# 186380                  0     low_fare
# 264084                  0    high_fare
# 374983                  0     low_fare
# 378056                  0     low_fare
# 458033                  0     low_fare

# %% [markdown]
# tenemos 7 casos donde la ubicacion destino no fue registrada, por el momento dejamos así los datos, más adelante imputaremos despues de checar atipicos

# %% [markdown]
# ## Presición/Orden

# %% [markdown]
# ### revisión de variables unitarias

# %%
def unitarias(df2,col):
    result=pd.DataFrame(df2[col].value_counts(1))
    if result.shape[0]>0:
        if (result.iloc[0,0]>.91) :
            print(f"{col} -- VARIABLE UNITARIA")

# %% [markdown]
# Revisamos para nuestra unica variable categorica

# %%
unitarias(df,'v_fare_class')

# %% [markdown]
# no la detecta como variable unitaria

# %% [markdown]
# ### variables categoricas

# %%
df['v_fare_class'].value_counts()
# Out:
# v_fare_class
# low_fare     543539
# high_fare     56461
# Name: count, dtype: int64

# %% [markdown]
# solo hay 2 categorias, y eso es correcto

# %% [markdown]
# ### variables numericas

# %% [markdown]
# **c_fare_amount**

# %%
df['c_fare_amount'].value_counts()
# Out:
# c_fare_amount
# 6.50      29082
# 4.50      24640
# 8.50      22536
# 5.30      17652
# 5.70      17554
#           ...
# 66.83         1
# 69.33         1
# 74.90         1
# 38.70         1
# 156.99        1
# Name: count, Length: 1785, dtype: int64

# %%
df['c_fare_amount'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# **c_pickup_longitude**

# %%
df['c_pickup_longitude'].value_counts()
# Out:
# c_pickup_longitude
#  0.000000     11365
# -73.137393      199
# -73.982100       54
# -73.981500       52
# -73.982095       51
#               ...
# -73.911205        1
# -73.926386        1
# -74.011292        1
# -73.941640        1
# -73.924725        1
# Name: count, Length: 99891, dtype: int64

# %%
df['c_pickup_longitude'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# **c_pickup_latitude**

# %%
df['c_pickup_latitude'].value_counts()
# Out:
# c_pickup_latitude
# 0.000000     11333
# 41.366138      199
# 40.774057       49
# 40.774037       48
# 40.774102       42
#              ...
# 40.744616        1
# 40.695135        1
# 40.814747        1
# 40.798321        1
# 40.804620        1
# Name: count, Length: 126242, dtype: int64

# %%
df['c_pickup_latitude'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# **c_dropoff_longitude**

# %%
df['c_dropoff_longitude'].value_counts()
# Out:
# c_dropoff_longitude
#  0.000000     11363
# -73.137393      148
# -73.982297       50
# -73.982300       45
# -73.984700       45
#               ...
# -76.462462        1
# -74.013588        1
# -73.923367        1
# -74.012744        1
# -73.933638        1
# Name: count, Length: 114894, dtype: int64

# %%
df['c_dropoff_longitude'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# **c_dropoff_latitude**

# %%
df['c_dropoff_latitude'].value_counts()
# Out:
# c_dropoff_latitude
# 0.000000     11333
# 41.366138      148
# 40.750062       39
# 40.750392       39
# 40.750107       38
#              ...
# 40.705151        1
# 40.762894        1
# 40.676660        1
# 40.708993        1
# 40.780975        1
# Name: count, Length: 144434, dtype: int64

# %%
df['c_dropoff_latitude'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# **c_passenger_count**

# %%
df['c_passenger_count'].value_counts()
# Out:
# c_passenger_count
# 1      415060
# 2       88628
# 5       42220
# 3       26323
# 4       12922
# 6       12716
# 0        2130
# 208         1
# Name: count, dtype: int64

# %%
df['c_passenger_count'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# todas parecen correctas

# %% [markdown]
# ### variable de fecha

# %%
df['d_pickup_datetime'].value_counts()
# Out:
# d_pickup_datetime
# 2010-03-15 18:24:00.000000800    2
# 2011-03-17 23:23:00.000000700    2
# 2014-09-03 10:35:00.000000110    2
# 2009-11-14 20:43:33.000000100    2
# 2011-10-26 07:22:00.000000300    2
#                                 ..
# 2013-03-16 03:55:45.000000100    1
# 2010-05-06 06:51:32.000000400    1
# 2009-01-25 05:33:38.000000100    1
# 2010-12-23 01:59:00.000000650    1
# 2014-09-03 20:35:37.000000400    1
# Name: count, Length: 599935, dtype: int64

# %%
df['d_pickup_datetime'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ## consistencia

# %% [markdown]
# ### variables numericas

# %% [markdown]
# **c_fare_amount**

# %%
df['c_fare_amount'].describe()
# Out:
# count    600000.000000
# mean         11.369602
# std           9.882086
# min         -44.900000
# 25%           6.000000
# 50%           8.500000
# 75%          12.500000
# max         495.000000
# Name: c_fare_amount, dtype: float64

# %% [markdown]
# vemos datos negativos, revisemos cuantos son

# %%
df[df['c_fare_amount'] < 0]
# Out:
#         c_fare_amount             d_pickup_datetime  c_pickup_longitude  \
# 41704           -2.50 2015-05-31 10:23:50.000000300          -73.982162
# 83429           -2.50 2015-01-15 17:33:24.000000100          -73.982567
# 85442           -3.00 2013-08-30 08:57:10.000000200          -73.995062
# 115048          -5.00 2015-03-09 10:29:46.000000400          -73.990974
# 121743          -6.50 2015-01-01 04:35:09.000000400          -73.993660
# 131862          -5.00 2015-06-26 01:13:18.000000200          -73.979797
# 159068          -4.50 2015-02-13 00:36:36.000000200          -74.006142
# 185707          -2.90 2010-02-10 12:33:10.000000400          -73.970775
# 210493          -3.00 2015-06-07 02:54:14.000000400          -73.913246
# 289810          -2.50 2010-03-09 18:18:10.000000600          -73.885183
# 307767          -2.50 2015-06-19 03:35:46.000000300          -73.994331
# 311992          -5.00 2015-02-18 07:22:53.000000500          -73.980362
# 323537          -2.90 2010-03-09 23:37:10.000000500          -73.789450
# 350507          -6.50 2010-03-13 00:10:10.000000500          -73.984355
# 351882          -2.50 2013-08-11 13:39:10.000000100          -73.785260
# 375267          -2.50 2015-03-22 05:14:27.000000100          -74.000031
# 434444          -3.00 2013-08-29 11:51:10.000000400          -73.984460
# 471679          -2.50 2015-02-26 15:12:43.000000600          -73.970779
# 493824         -18.10 2010-03-14 14:07:10.000000400          -73.958278
# 540314         -44.90 2010-02-19 23:47:10.000000200          -73.871120
# 550621          -2.50 2015-04-30 15:19:45.000000300          -73.952187
# 555483          -6.50 2010-03-12 12:17:10.000000100          -73.989493
# 569479          -2.50 2015-01-17 19:13:41.000000600          -73.956787
# 569507          -2.50 2015-01-11 14:34:09.000000400          -73.985229
# 579340         -29.87 2010-02-08 09:04:10.000000300          -73.863158
#
#         c_pickup_latitude  c_dropoff_longitude  c_dropoff_latitude  \
# 41704           40.773621           -73.982094           40.773811
# 83429           40.739799           -73.982567           40.739799
# 85442           40.740755           -73.995885           40.741357
# 115048          40.755985           -73.980820           40.759869
# 121743          40.746986           -73.980347           40.742802
# 131862          40.743240           -73.981216           40.737240
# 159068          40.740425           -74.009827           40.738804
# 185707          40.783425           -73.973443           40.779775
# 210493          40.766212           -73.914963           40.764065
# 289810          40.772840           -73.885178           40.772838
# 307767          40.717243           -73.994370           40.717247
# 311992          40.765751           -73.988449           40.770851
# 323537          40.643498           -73.788665           40.641952
# 350507          40.728967           -73.966578           40.754877
# 351882          40.648442             0.000000            0.000000
# 375267          40.720631           -73.999809           40.720539
# 434444          40.759835           -73.985620           40.757950
# 471679          40.764351           -73.971466           40.764503
# 493824          40.760293           -74.010582           40.711573
# 540314          40.773902           -73.676533           40.786890
# 550621          40.790112           -73.950043           40.792839
# 555483          40.730085           -73.975762           40.749307
# 569479          40.745770           -73.956757           40.744591
# 569507          40.735886           -73.985428           40.735535
# 579340          40.769440           -73.975303           40.749783
#
#         c_passenger_count v_fare_class
# 41704                   2     low_fare
# 83429                   2     low_fare
# 85442                   4     low_fare
# 115048                  1     low_fare
# 121743                  1     low_fare
# 131862                  6     low_fare
# 159068                  1     low_fare
# 185707                  1     low_fare
# 210493                  5     low_fare
# 289810                  1     low_fare
# 307767                  1     low_fare
# 311992                  1     low_fare
# 323537                  1     low_fare
# 350507                  1     low_fare
# 351882                  1     low_fare
# 375267                  1     low_fare
# 434444                  1     low_fare
# 471679                  1     low_fare
# 493824                  3     low_fare
# 540314                  1     low_fare
# 550621                  1     low_fare
# 555483                  1     low_fare
# 569479                  1     low_fare
# 569507                  1     low_fare
# 579340                  1     low_fare

# %% [markdown]
# la target contiene valores negativos, esto no es algo consistente, tenemos 3 opciones para solucionarlo
# 1. Convertirlo a Nulo para despues imputar
# 2. Pasar el valor a positivo
# 3. Eliminar los registros
#
# Si fuera el caso de alguna feature se podría aplicar el 1 sin problema, al ser la target es mejor no alterarla y dejarla tal y como esta, por lo mismo no aplicaria el segundo caso (a menos que estuvieramos 100% seguros que fue solo un error de signo). Al ser pocos registros es mejor eliminnarlos

# %%
df = df.loc[df['c_fare_amount'] >= 0]

# %% [markdown]
# **c_pickup_longitude y c_pickup_latitude**

# %%
df['c_pickup_longitude'].describe()
# Out:
# count    599975.000000
# mean        -72.515167
# std          12.877422
# min       -3377.680935
# 25%         -73.992057
# 50%         -73.981785
# 75%         -73.967090
# max        2522.271325
# Name: c_pickup_longitude, dtype: float64

# %% [markdown]
# la longitud solo tiene valores aceptables de -180 a 180 y se pueden ver casos que no estan en este rango

# %%
df[(df['c_pickup_longitude'] < -180 )| (df['c_pickup_longitude'] > 180 )]
# Out:
#         c_fare_amount             d_pickup_datetime  c_pickup_longitude  \
# 114220           17.3 2012-03-22 21:40:00.000000188         2522.271325
# 122394            6.5 2012-07-21 15:23:00.000000930         -736.416665
# 206343           11.5 2013-05-23 15:23:00.000000700         -735.888333
# 366493            5.3 2011-10-28 13:53:00.000000178        -3377.680935
# 380235           16.9 2011-10-28 10:53:00.000000800        -1452.988333
# 403077            6.1 2012-06-03 23:21:00.000000770         -740.000000
# 425880            4.1 2012-03-11 01:56:00.000000100        -2986.242495
# 444375            9.7 2011-11-21 21:36:00.000000810         2140.601160
#
#         c_pickup_latitude  c_dropoff_longitude  c_dropoff_latitude  \
# 114220        2621.628430         -1718.117653        -2864.471003
# 122394          40.752285           -73.992565           40.742687
# 206343          40.760863           -73.989835           40.738443
# 366493        -113.019497          -554.918693          314.794180
# 380235          40.776000           -73.989487           40.740667
# 403077          40.747620             0.000000            0.000000
# 425880        -880.627428         -3383.296608        -2559.748913
# 444375        1703.092772         -1251.195890        -1189.615440
#
#         c_passenger_count v_fare_class
# 114220                  1     low_fare
# 122394                  1     low_fare
# 206343                  5     low_fare
# 366493                  1     low_fare
# 380235                  2     low_fare
# 403077                  6     low_fare
# 425880                  1     low_fare
# 444375                  1     low_fare

# %% [markdown]
# estos casos los vamos a dejar en null para despues imputar

# %%
df.loc[(df['c_pickup_longitude'] < -180 )| (df['c_pickup_longitude'] > 180 ),'c_pickup_longitude'] = np.nan

# %%
df['c_pickup_latitude'].describe()
# Out:
# count    599975.000000
# mean         39.923526
# std           8.465064
# min       -3116.285383
# 25%          40.734945
# 50%          40.752730
# 75%          40.767213
# max        2621.628430
# Name: c_pickup_latitude, dtype: float64

# %% [markdown]
# caso similar pasa para la latitud, solo que esta solo acepta valores de -90 a 90

# %%
df.loc[(df['c_pickup_latitude'] < -90 )| (df['c_pickup_latitude'] > 90 )]
# Out:
#         c_fare_amount             d_pickup_datetime  c_pickup_longitude  \
# 64516             5.3 2012-05-24 22:44:00.000000880          -73.989188
# 114220           17.3 2012-03-22 21:40:00.000000188                 NaN
# 133946            6.9 2012-03-05 20:58:00.000000900          -73.994268
# 220755           25.3 2012-08-03 07:43:00.000000176            0.000000
# 366493            5.3 2011-10-28 13:53:00.000000178                 NaN
# 425880            4.1 2012-03-11 01:56:00.000000100                 NaN
# 431544            5.7 2012-04-12 07:31:00.000000270          -73.957087
# 444375            9.7 2011-11-21 21:36:00.000000810                 NaN
# 550298            8.5 2012-03-16 08:13:00.000000272          -73.994277
#
#         c_pickup_latitude  c_dropoff_longitude  c_dropoff_latitude  \
# 64516           91.266667           -73.982362           40.763105
# 114220        2621.628430         -1718.117653        -2864.471003
# 133946         404.966667           -73.973857           40.755457
# 220755       -3116.285383           -73.953600           40.787998
# 366493        -113.019497          -554.918693          314.794180
# 425880        -880.627428         -3383.296608        -2559.748913
# 431544         424.083332           -73.968312           40.765117
# 444375        1703.092772         -1251.195890        -1189.615440
# 550298         405.133332           -73.956763           40.783737
#
#         c_passenger_count v_fare_class
# 64516                   1     low_fare
# 114220                  1     low_fare
# 133946                  1     low_fare
# 220755                  1    high_fare
# 366493                  1     low_fare
# 425880                  1     low_fare
# 431544                  1     low_fare
# 444375                  1     low_fare
# 550298                  1     low_fare

# %% [markdown]
# de igual forma convertimos a null para despues imputar

# %%
df.loc[(df['c_pickup_latitude'] < -90 )| (df['c_pickup_latitude'] > 90 ),'c_pickup_latitude']  = np.nan

# %% [markdown]
# **c_dropoff_longitude y	c_dropoff_latitude**

# %%
df['c_dropoff_longitude'].describe()
# Out:
# count    599968.000000
# mean        -72.524262
# std          11.833467
# min       -3383.296608
# 25%         -73.991383
# 50%         -73.980102
# 75%         -73.963607
# max          40.851027
# Name: c_dropoff_longitude, dtype: float64

# %%
df[(df['c_dropoff_longitude'] < -180 )| (df['c_dropoff_longitude'] > 180 )]
# Out:
#         c_fare_amount             d_pickup_datetime  c_pickup_longitude  \
# 33273             5.7 2012-02-09 17:42:00.000000178          -74.006390
# 100812            6.1 2012-06-19 07:41:00.000000190          -73.982467
# 108096            6.9 2012-01-28 16:51:00.000000880          -73.983142
# 114220           17.3 2012-03-22 21:40:00.000000188                 NaN
# 295526            8.1 2012-02-18 00:22:00.000000100          -73.991215
# 366493            5.3 2011-10-28 13:53:00.000000178                 NaN
# 425880            4.1 2012-03-11 01:56:00.000000100                 NaN
# 434751           17.7 2012-05-24 09:00:00.000000101          -73.997572
# 444375            9.7 2011-11-21 21:36:00.000000810                 NaN
# 573884            4.9 2012-03-16 22:02:00.000000257          -73.992605
#
#         c_pickup_latitude  c_dropoff_longitude  c_dropoff_latitude  \
# 33273           40.739552          -740.066667           40.724792
# 100812          40.771612          -736.416665           40.764310
# 108096          40.741987          -736.500000           40.755255
# 114220                NaN         -1718.117653        -2864.471003
# 295526          40.750727          -740.000000           40.726617
# 366493                NaN          -554.918693          314.794180
# 425880                NaN         -3383.296608        -2559.748913
# 434751          40.720945         -1329.621332           40.773717
# 444375                NaN         -1251.195890        -1189.615440
# 573884          40.726815          -472.266667           40.733332
#
#         c_passenger_count v_fare_class
# 33273                   1     low_fare
# 100812                  1     low_fare
# 108096                  1     low_fare
# 114220                  1     low_fare
# 295526                  1     low_fare
# 366493                  1     low_fare
# 425880                  1     low_fare
# 434751                  1     low_fare
# 444375                  1     low_fare
# 573884                  1     low_fare

# %% [markdown]
# convertimos a null

# %%
df.loc[(df['c_dropoff_longitude'] < -180 )| (df['c_dropoff_longitude'] > 180 ),'c_dropoff_longitude'] = np.nan

# %%
df.loc[(df['c_dropoff_latitude'] < -90 )| (df['c_dropoff_latitude'] > 90 )]
# Out:
#         c_fare_amount             d_pickup_datetime  c_pickup_longitude  \
# 114220           17.3 2012-03-22 21:40:00.000000188                 NaN
# 117668           30.5 2012-05-02 14:20:00.000000131          -73.870875
# 157185           28.9 2011-09-27 11:54:00.000000127          -74.014595
# 293101           15.3 2012-05-21 12:15:00.000000980          -74.001292
# 342980           18.0 2013-08-14 20:23:00.000000245          -73.999190
# 366493            5.3 2011-10-28 13:53:00.000000178                 NaN
# 391915           19.3 2012-02-26 00:25:00.000000850          -74.006457
# 413069            6.5 2012-01-03 09:04:00.000000130          -74.008918
# 425880            4.1 2012-03-11 01:56:00.000000100                 NaN
# 444375            9.7 2011-11-21 21:36:00.000000810                 NaN
#
#         c_pickup_latitude  c_dropoff_longitude  c_dropoff_latitude  \
# 114220                NaN                  NaN        -2864.471003
# 117668          40.773792           -73.977790          404.716667
# 157185          40.681880           -73.973310          404.616667
# 293101          40.727560           -73.953047          404.466667
# 342980          40.720200            -0.360000        -3114.338567
# 366493                NaN                  NaN          314.794180
# 391915          40.743865           -73.981283          404.133332
# 413069          40.717827           -74.000855          404.133332
# 425880                NaN                  NaN        -2559.748913
# 444375                NaN                  NaN        -1189.615440
#
#         c_passenger_count v_fare_class
# 114220                  1     low_fare
# 117668                  1    high_fare
# 157185                  1    high_fare
# 293101                  1     low_fare
# 342980                  1     low_fare
# 366493                  1     low_fare
# 391915                  1     low_fare
# 413069                  1     low_fare
# 425880                  1     low_fare
# 444375                  1     low_fare

# %% [markdown]
# convertimos a null

# %%
df.loc[(df['c_dropoff_latitude'] < -90 )| (df['c_dropoff_latitude'] > 90 ),'c_dropoff_latitude'] = np.nan

# %% [markdown]
# **c_passenger_count**

# %%
df['c_passenger_count'].value_counts()
# Out:
# c_passenger_count
# 1      415041
# 2       88626
# 5       42219
# 3       26322
# 4       12921
# 6       12715
# 0        2130
# 208         1
# Name: count, dtype: int64

# %% [markdown]
# En  un taxi siempre tiene que ir una persona, y si es una comioneta el maximo de pasajeros es 7, así revisemos si hay datos con 0 o más de 7 pasajeros
#
# nota: Actualmente en apps como Uber es posible enviar un paquete y en ese caso sería un envio con 0 pasajeros, en tal caso registros con 0 pasajeros serían validos, sin embargo, no se especifica en la descripcion del problema, este tipo de decisiones se tiene que ver con los encargados del negocio, en esete caso al ser un problema de practica podemos tomar la decicion nosotros mismos, en este caso se decide convertir a nulo esos caso para despues imputar

# %%
df[(df['c_passenger_count'] == 0) | (df['c_passenger_count'] > 7)]
# Out:
#         c_fare_amount             d_pickup_datetime  c_pickup_longitude  \
# 98                4.5 2011-12-25 17:49:31.000000200          -73.991800
# 159              13.3 2012-02-10 07:30:55.000000100          -73.970885
# 946               6.9 2011-12-28 09:01:25.000000100          -73.974500
# 1436              4.9 2012-03-25 19:45:07.000000200          -74.002523
# 1719              9.7 2011-07-15 18:57:37.000000300          -73.966000
# ...               ...                           ...                 ...
# 597842            5.7 2011-04-13 23:17:55.000000500          -73.989423
# 597979            6.1 2011-06-10 06:13:43.000000200          -73.960000
# 598768           18.1 2012-02-08 16:48:25.000000300          -73.983998
# 599330            6.5 2011-07-06 22:26:14.000000300            0.000000
# 599441            3.3 2012-03-11 00:07:58.000000100          -73.949943
#
#         c_pickup_latitude  c_dropoff_longitude  c_dropoff_latitude  \
# 98              40.749500           -73.988600           40.738700
# 159             40.748450           -74.005880           40.706427
# 946             40.732900           -73.984200           40.746200
# 1436            40.734180           -74.007907           40.718617
# 1719            40.805400           -73.982600           40.772100
# ...                   ...                  ...                 ...
# 597842          40.747702           -73.968823           40.756543
# 597979          40.782000           -73.976400           40.759000
# 598768          40.759427           -74.003418           40.706260
# 599330           0.000000             0.000000            0.000000
# 599441          40.802210           -73.957210           40.804650
#
#         c_passenger_count v_fare_class
# 98                      0     low_fare
# 159                     0     low_fare
# 946                     0     low_fare
# 1436                    0     low_fare
# 1719                    0     low_fare
# ...                   ...          ...
# 597842                  0     low_fare
# 597979                  0     low_fare
# 598768                  0     low_fare
# 599330                  0     low_fare
# 599441                  0     low_fare
#
# [2131 rows x 8 columns]

# %%
df.loc[(df['c_passenger_count'] == 0) | (df['c_passenger_count'] > 7),'c_passenger_count'] = np.nan

# %% [markdown]
# ## Variable de fecha

# %%
df['d_pickup_datetime'].describe()
# Out:
# count                           599975
# mean     2012-03-21 23:45:20.126089984
# min      2009-01-01 00:00:46.000000200
# 25%      2010-08-20 13:29:42.000000256
# 50%      2012-03-20 17:46:27.000000512
# 75%         2013-10-19 16:57:10.500000
# max      2015-06-30 23:53:23.000000200
# Name: d_pickup_datetime, dtype: object

# %%
df['d_pickup_datetime'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ahora que hemos convertido varios registros a null revisemos si hay casos donde el 50% o más de variables son nulas, no nos conviene tener registros donde la mayoria son nulos

# %%
df[df.isnull().sum(axis=1) >= 4]
# Out:
#         c_fare_amount             d_pickup_datetime  c_pickup_longitude  \
# 114220           17.3 2012-03-22 21:40:00.000000188                 NaN
# 366493            5.3 2011-10-28 13:53:00.000000178                 NaN
# 425880            4.1 2012-03-11 01:56:00.000000100                 NaN
# 444375            9.7 2011-11-21 21:36:00.000000810                 NaN
#
#         c_pickup_latitude  c_dropoff_longitude  c_dropoff_latitude  \
# 114220                NaN                  NaN                 NaN
# 366493                NaN                  NaN                 NaN
# 425880                NaN                  NaN                 NaN
# 444375                NaN                  NaN                 NaN
#
#         c_passenger_count v_fare_class
# 114220                1.0     low_fare
# 366493                1.0     low_fare
# 425880                1.0     low_fare
# 444375                1.0     low_fare

# %% [markdown]
# estos registros lo eliminamos

# %%
df = df.loc[df.isnull().sum(axis=1) < 4]

# %%
df
# Out:
#         c_fare_amount             d_pickup_datetime  c_pickup_longitude  \
# 0                12.5 2012-11-11 13:45:00.000000290          -73.956322
# 1                11.3 2010-01-26 00:13:00.000000500          -73.982577
# 2                19.5 2014-10-07 19:24:00.000000235          -73.972000
# 3                10.5 2012-10-20 13:48:40.000000200          -74.002701
# 4                 7.0 2014-04-29 20:27:00.000000186          -73.982517
# ...               ...                           ...                 ...
# 599995           14.5 2010-07-20 09:21:00.000000520          -73.979120
# 599996            3.5 2013-02-20 15:16:27.000000400          -73.955352
# 599997            7.3 2010-10-07 22:32:00.000000223            0.000000
# 599998            4.1 2010-09-13 13:28:00.000000138          -73.973527
# 599999            8.0 2014-09-03 20:35:37.000000400          -73.996540
#
#         c_pickup_latitude  c_dropoff_longitude  c_dropoff_latitude  \
# 0               40.813427           -73.959143           40.783220
# 1               40.746018           -73.980713           40.780807
# 2               40.759470           -74.006190           40.708460
# 3               40.728209           -74.013599           40.710990
# 4               40.770782           -73.979932           40.754880
# ...                   ...                  ...                 ...
# 599995          40.746182           -74.004187           40.705937
# 599996          40.804620           -73.955352           40.804620
# 599997           0.000000             0.000000            0.000000
# 599998          40.784913           -74.001877           40.740657
# 599999          40.747920           -73.979322           40.762122
#
#         c_passenger_count v_fare_class
# 0                     1.0     low_fare
# 1                     1.0     low_fare
# 2                     2.0     low_fare
# 3                     1.0     low_fare
# 4                     1.0     low_fare
# ...                   ...          ...
# 599995                1.0     low_fare
# 599996                1.0     low_fare
# 599997                2.0     low_fare
# 599998                6.0     low_fare
# 599999                1.0     low_fare
#
# [599971 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# c_fare_amount             0
# d_pickup_datetime         0
# c_pickup_longitude        4
# c_pickup_latitude         5
# c_dropoff_longitude      13
# c_dropoff_latitude       13
# c_passenger_count      2131
# v_fare_class              0
# dtype: int64

# %% [markdown]
# # Análisis Exploratorio

# %%
palette = sns.color_palette("pastel")

# %% [markdown]
# En la siguiente gráfica vemos que la mayor parte de los registros corresponden a tarifas bajas

# %%
prop = df['v_fare_class'].value_counts(normalize=True) * 100

ax = sns.barplot(x=prop.index, y=prop.values, palette = palette)
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=10, color='black', xytext=(0, 5), textcoords='offset points')


plt.xlabel('v_fare_class')
plt.ylabel('Porcentaje')
plt.title('Gráfica de barras para v_fare_class')

plt.show()

# %%
sns.histplot(data=df, x='c_fare_amount',bins = 15, color = palette[0])

plt.xlabel('Monto')
plt.ylabel('Frecuencia')
plt.title('Histograma del monto de la tarifa')
# Out:
# Text(0.5, 1.0, 'Histograma del monto de la tarifa')

# %% [markdown]
# En la gráfica anterior vemos posibles datos atipicos, vamos a omitir estos datos para tener una mejor vision del histogramam, en el siguiente histograma observamos que la distribución es asimetrica hacia la derecha, y se ve una distribucion de cola ligera

# %%
sns.histplot(data=df.loc[df['c_fare_amount'] < 100], x='c_fare_amount',bins = 15, color = palette[0])

plt.xlabel('Monto')
plt.ylabel('Frecuencia')
plt.title('Histograma del monto de la tarifa')
# Out:
# Text(0.5, 1.0, 'Histograma del monto de la tarifa')

# %%
ax = sns.boxplot(y='c_fare_amount', data=df,palette=palette)
ax.set_ylim(0, 100)
plt.xlabel('')
plt.ylabel('Mont')
plt.title('Gráfico de Caja y Bigotes del monto de tarifa')

plt.show()

# %%
df['c_fare_amount'].describe()
# Out:
# count    599971.000000
# mean         11.370377
# std           9.881412
# min           0.000000
# 25%           6.000000
# 50%           8.500000
# 75%          12.500000
# max         495.000000
# Name: c_fare_amount, dtype: float64

# %% [markdown]
# en la grafica anterior de caja y bigotes y en las estadisticas podemos observar que el 75% del monto se encuentra entre 0 y 12.5,como ya vimos anteriormente hay muchos datos extremos y se aprecia más en el grafico de caja y bigotes, en la siguiente gráfica podemos ver que los datos extremos justamente pertenencen a la tarifa alto, lo cual quiere decir que aunque son datos extremos es correcto el monto, este monto se pudo deber a que el viaje fue largo o fue en un día festivo

# %%
ax = sns.boxplot(x='v_fare_class',y='c_fare_amount', data=df,palette=palette)
ax.set_ylim(0, 100)
plt.xlabel('Tipo tarifa')
plt.ylabel('Mont')
plt.title('Gráfico de Caja y Bigotes del monto de tarifa por tipo de tarifa')

plt.show()

# %% [markdown]
# En la siguiente gráfica observamos que la mayoria de viajes solo los hacen con un pasajeros, el segundo caso más comun es con 2 pasajeros y luego los demas

# %%
prop = df['c_passenger_count'].value_counts(normalize=True) * 100
ax = sns.barplot(x=prop.index, y=prop.values, palette = palette)
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=10, color='black', xytext=(0, 5), textcoords='offset points')


plt.xlabel('pasajeros')
plt.ylabel('Frecuencia')
plt.title('Gráfica de barras de pasajeros')
# Out:
# Text(0.5, 1.0, 'Gráfica de barras de pasajeros')

# %% [markdown]
# En la siguiente gráfica observamos que no hay una relación aparente entre el número de pasajeros y el monto de la tarifa, esto es logico pues en los taxis generalmente se cobra por la distancia recorrida y no por persona

# %%
ax = sns.boxplot(x='c_passenger_count',y='c_fare_amount', data=df,palette=palette)
ax.set_ylim(0, 50)
plt.xlabel('Pasajeros')
plt.ylabel('Monto')
plt.title('Gráfico de Caja y Bigotes del monto de tarifa por número de pasajers')

plt.show()

# %% [markdown]
# En el siguiente gráfico podemos confirmar lo menciona, no hay mucha diferencia entre la distribucion de cuando hay 1,2,3,4,5 o 6 pasajeros

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(12, 8))
unic = df.loc[~df['c_passenger_count'].isnull(),'c_passenger_count'].unique()
for i, categoria in enumerate(unic):
    data_categoria = df[df['c_passenger_count'] == categoria]
    
    
    ax = sns.histplot(data=df['c_fare_amount'], ax=axes[i//3, i%3], bins=40, stat = 'probability', color = palette[0])
    ax.set_xlim(0, 100)
    axes[i//3, i%3].set_title(f'Categoría {categoria}')
    axes[i//3, i%3].set_xlabel('Frecuencia Relativa')
    axes[i//3, i%3].set_ylabel('Densidad')

plt.tight_layout()

plt.show()

# %% [markdown]
# vamos a hacer un agrupado por día para hacer un analisis del numero de viajes por día

# %%
agrupado_por_dia = df.groupby(df['d_pickup_datetime'].dt.date)['d_pickup_datetime'].count().reset_index(name='num_registros')
agrupado_por_dia['d_pickup_datetime'] = pd.to_datetime(agrupado_por_dia['d_pickup_datetime'])

# %%
sns.lineplot(x="d_pickup_datetime", y="num_registros",data=agrupado_por_dia, color = palette[0])
plt.xlabel('Día')
plt.ylabel('Número de Registros')
plt.title('Número de Registros por Día')
plt.xticks(rotation=45) 

plt.show()

# %% [markdown]
# Se aprecia mucho ruido en la seríe anterior, pero podemos decir que no hay una tendencia aparente , la media y varianza parecen constantes(sobre todo la media, la varianza parece aumentar en ciertas fechas), vamos a hacer un grafico por mes, primero vamos a crear un nuevo dataframe ya agregar columnas como el mes, dia y dia de la semana, esto para analisis

# %%
df2 = df.copy()
df2['mes'] = df2['d_pickup_datetime'].dt.month
df2['dia_del_mes'] = df2['d_pickup_datetime'].dt.day
df2['dia_de_la_semana'] = df2['d_pickup_datetime'].dt.dayofweek
df2['hora'] = df2['d_pickup_datetime'].dt.hour
df2['es_fin_de_semana'] = (df2['d_pickup_datetime'].dt.dayofweek >= 5)
df2['mes_anio'] = df2['d_pickup_datetime'].dt.strftime('%Y-%m')
df2['anio'] = df2['d_pickup_datetime'].dt.year

# %%
agrupado_por_mes = df2.groupby(df2['mes_anio'])['d_pickup_datetime'].count().reset_index(name='num_registros')
agrupado_por_mes['mes_anio'] = pd.to_datetime(agrupado_por_mes['mes_anio'])
sns.lineplot(x="mes_anio", y="num_registros",data=agrupado_por_mes, color = palette[0])
plt.xlabel('FECHA')
plt.ylabel('Número de Registros')
plt.title('Número de Registros por MES')
plt.xticks(rotation=45) 

plt.show()

# %% [markdown]
# vemos que hay temporadas donde aumenta y baja el número de viajes, podemos graficar un sesonalplot para apreciar si hay algun tipo de estacionalidad, en el siguiente grafico podemos ver que si hay cierto patron por mes, en febrero bajan la cantidad de viajes, suben en marzo,empiezan a bajar en julio - agosto y empiezan a subir en septiembre

# %%
agrupado_por_mes = df2.groupby(['mes','anio'])['d_pickup_datetime'].count().reset_index(name='num_registros')
sns.lineplot(x="mes", y="num_registros", hue="anio", data=agrupado_por_mes, palette=palette, markers=True, legend="full")
plt.xlabel('FECHA')
plt.ylabel('Número de Registros')
plt.title('seasonplot por  MES')
plt.xticks(rotation=45) 

plt.show()
# Out:
# /tmp/ipykernel_57487/2366654437.py:2: UserWarning: The palette list has more values (10) than needed (7), which may not be intended.
#   sns.lineplot(x="mes", y="num_registros", hue="anio", data=agrupado_por_mes, palette=palette, markers=True, legend="full")

# %% [markdown]
# en el siguiente grafico se hace lo mismo por dia de més, sin embargo no se ve un patron como en los mese

# %%
agrupado_por_mes = df2.groupby(['dia_del_mes','mes_anio'])['d_pickup_datetime'].count().reset_index(name='num_registros')
ax = sns.lineplot(x="dia_del_mes", y="num_registros", hue='mes_anio', data=agrupado_por_mes, palette=palette, markers=True,
                  legend=False)
ax.legend( loc='upper left', bbox_to_anchor=(1, 1))
plt.xlabel('FECHA')
plt.ylabel('Número de Registros')
plt.title('Sesonplot por   dia del mes')
plt.xticks(rotation=45) 

plt.show()
# Out:
# /tmp/ipykernel_57487/1098254326.py:2: UserWarning:
# The palette list has fewer values (10) than needed (78) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.lineplot(x="dia_del_mes", y="num_registros", hue='mes_anio', data=agrupado_por_mes, palette=palette, markers=True,
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# En el siguiente gráfico realizamos un promedio del monto por mes, vemos que aunque en la cantidad de viajes no hay tendencia, en el precio del monto si.

# %%
agrupado_por_mes = df2.groupby(df2['mes_anio'])['c_fare_amount'].mean().reset_index(name='promedio')
agrupado_por_mes['mes_anio'] = pd.to_datetime(agrupado_por_mes['mes_anio'])
sns.lineplot(x="mes_anio", y="promedio",data=agrupado_por_mes, color = palette[0])
plt.xlabel('FECHA')
plt.ylabel('promedio del monto')
plt.title('promedio del monto por MES')
plt.xticks(rotation=45) 

plt.show()

# %% [markdown]
# Tanto en la gráfica anterior como en la siguiente se ve un poco de estacionaliedad, en los primeros/ultimos meses del año el precio baja, y de junio a octubre los precios suben

# %%
agrupado_por_mes = df2.groupby(['mes','anio'])['c_fare_amount'].mean().reset_index(name='promedio')
ax = sns.lineplot(x="mes", y="promedio", hue="anio", data=agrupado_por_mes, palette=palette, markers=True, legend="full")
ax.legend( loc='upper left', bbox_to_anchor=(1, 1))
plt.xlabel('mes')
plt.ylabel('promedio')
plt.title('seasonplot del promedio del monto por  MES')
plt.xticks(rotation=45) 

plt.show()
# Out:
# /tmp/ipykernel_57487/3971733734.py:2: UserWarning: The palette list has more values (10) than needed (7), which may not be intended.
#   ax = sns.lineplot(x="mes", y="promedio", hue="anio", data=agrupado_por_mes, palette=palette, markers=True, legend="full")

# %% [markdown]
# para el día del més no parece haber un patron, al igual que en la cantidad de viaes

# %%
agrupado_por_mes = df2.groupby(['dia_del_mes','mes_anio'])['c_fare_amount'].mean().reset_index(name='promedio')
ax = sns.lineplot(x="dia_del_mes", y="promedio", hue='mes_anio', data=agrupado_por_mes, palette=palette, markers=True,
                  legend=False)
ax.legend( loc='upper left', bbox_to_anchor=(1, 1))
plt.xlabel('Día')
plt.ylabel('promedio de monto')
plt.title('Sesonplot del promedio del monto dia del mes')
plt.xticks(rotation=45) 

plt.show()
# Out:
# /tmp/ipykernel_57487/3780734629.py:2: UserWarning:
# The palette list has fewer values (10) than needed (78) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.lineplot(x="dia_del_mes", y="promedio", hue='mes_anio', data=agrupado_por_mes, palette=palette, markers=True,
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# haciendo un diagrama de caja y bigotes por dia de la semana tampoco se ve que el día de la semana afecte en el precio de la tarif

# %%
ax = sns.boxplot(x='dia_de_la_semana',y='c_fare_amount', data=df2,palette=palette)
ax.set_ylim(0, 50)
plt.xlabel('DIA DE LA SEMANA')
plt.ylabel('Monto')
plt.title('Gráfico de Caja y Bigotes del monto de tarifa por número de dia de la semana')

plt.show()

# %% [markdown]
# En el siguiente gráfico vemos que la horasi afecta en el monto de la tarifa, para horas entre las 12 y las vemos que las cajas son más grande abarcando más espacio hacia arriba, lo que indica que en estos horarios hay más variacion en los precios y son más comunes precios un poco altos

# %%
ax = sns.boxplot(x='hora',y='c_fare_amount', data=df2,palette=palette)
ax.set_ylim(0, 50)
plt.xlabel('Hora')
plt.ylabel('Monto')
plt.title('Gráfico de Caja y Bigotes del monto de tarifa por Hora del viaje')

plt.show()

# %% [markdown]
# Observamos que principalmente la hora y el més influyen en el precio del monto

# %% [markdown]
# **c_pickup_longitude y c_pickup_latitude**

# %% [markdown]
# revisemos una vista rapida de longitud vs latitud de inicio de viaje

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
plt.scatter(df['c_pickup_longitude'], df['c_pickup_latitude'], c='red', marker='o')

plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.title('Puntos Geográficos')
plt.grid(True)
plt.show()

# %% [markdown]
# vemos que los datos estan muy dispersos, vamos a crear grupos y calcular la media de cada grupo, tomar ese punto como referencia y graficarlo en un mapa, promero creamos los grupos, tomando como referencia que aquellos que esten a menos de un umbral de distancia (0.1) pertenezcan a un grupo, si no, se excluyen del grupo

# %%
df2['Grupo'] = -1
df2 = df2.loc[~((df2['c_pickup_longitude'].isnull()) | (df2['c_pickup_latitude'].isnull()) | (df2['c_dropoff_longitude'].isnull()) | (df2['c_dropoff_latitude'].isnull()))]

# Umbral de distancia (en kilómetros) para definir si dos puntos están cerca.
pip install geopandas
df['Grupo']

# %% [markdown]
# Ahora que tenemos los grupos calculamos la media y hacemos una grafica sencilla

# %% [markdown]
# import pandas as pd
# from geopy.distance import great_circle
#
#
# df2['Grupo'] = -1
#
# umbral_distancia = 0.1
#
# def asignar_grupos_y_calcular_media(row):
#     global grupo_counter
#     grupo_counter += 1
#     df2.loc[(df2['Grupo'] == -1) & (great_circle((row['c_pickup_latitude'], row['c_pickup_longitude']), (df2['c_pickup_latitude'], df2['c_pickup_longitude'])).km < umbral_distancia), 'Grupo'] = grupo_counter
#     return (df2[(df2['Grupo'] == grupo_counter)]['c_pickup_latitude'].mean(), df2[(df2['Grupo'] == grupo_counter)]['c_pickup_longitude'].mean())
#
# grupo_counter = -1
# while len(df2[df2['Grupo'] == -1]) > 0:
#     df2['Latitud Media pickup'], df2['Longitud Media pickup'] = zip(*df2.apply(asignar_grupos_y_calcular_media, axis=1))
#
#
#
# #df3 = df2.drop_duplicates(subset=['Latitud Media', 'Longitud Media'], keep='first')
#
# #df3 = df3.drop(['Grupo'], axis=1)
